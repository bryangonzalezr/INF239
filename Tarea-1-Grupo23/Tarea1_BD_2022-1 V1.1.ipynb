# %% [markdown]
# # Tarea 1 Bases de Datos 2022-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Nombre Integrante 1 - Rol-1
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - ToolKit **sqlalchemy**
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (recuerde actualizar pip3):

# %%
! pip3 install ipython-sql
! pip3 install sqlalchemy
! pip3 install psycopg2

#Use to generate names
! pip3 install names
# Out:
# Requirement already satisfied: ipython-sql in f:\python\lib\site-packages (0.4.0)
# Requirement already satisfied: prettytable<1 in f:\python\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython-genutils>=0.1.0 in f:\python\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in f:\python\lib\site-packages (from ipython-sql) (8.2.0)
# Requirement already satisfied: sqlparse in f:\python\lib\site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: six in f:\python\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in f:\python\lib\site-packages (from ipython-sql) (1.4.34)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.28)
# Requirement already satisfied: matplotlib-inline in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: decorator in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: stack-data in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: colorama in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: pickleshare in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: backcall in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (58.1.0)
# Requirement already satisfied: traitlets>=5 in f:\python\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in f:\python\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in f:\python\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in f:\python\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: asttokens in f:\python\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.5)
# Requirement already satisfied: executing in f:\python\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: pure-eval in f:\python\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Requirement already satisfied: sqlalchemy in f:\python\lib\site-packages (1.4.34)
# Requirement already satisfied: greenlet!=0.4.17 in f:\python\lib\site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: psycopg2 in f:\python\lib\site-packages (2.9.3)
# Requirement already satisfied: names in f:\python\lib\site-packages (0.3.0)

# %% [markdown]
# ## Importar dependencias

# %%
from datetime import datetime
import random as r
import names
import string

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:12345@localhost:5432/Blockchain
# Out:
# env: DATABASE_URL=postgresql://postgres:12345@localhost:5432/Blockchain

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
connection = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='Blockchain',
   password="12345"
)

print(connection)
cursor = connection.cursor()
# Out:
# <connection object at 0x000001F546368480; dsn: 'user=postgres password=xxx dbname=Blockchain host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Usuarios"

# %%
# %%sql
#
# CREATE TABLE Usuarios(
#     ID_usuario INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR (45) NOT NULL,
#     apellido VARCHAR (45),
#     correo VARCHAR (45) NOT NULL,
#     contraseña VARCHAR(50) NOT NULL,
#     fecha_registro TIMESTAMP NOT NULL,
#     PRIMARY KEY(ID_usuario)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# (psycopg2.errors.DuplicateTable) la relación «usuarios» ya existe
#
# [SQL: CREATE TABLE Usuarios( ID_usuario INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR (45) NOT NULL,
#     apellido VARCHAR (45),
#     correo VARCHAR (45) NOT NULL,
#     contraseña VARCHAR(50) NOT NULL,
#     fecha_registro TIMESTAMP NOT NULL,
#     PRIMARY KEY(ID_usuario)
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Tabla "Creadores"

# %%
# %%sql
#
# CREATE TABLE Creadores(
#     Id_creador INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     apellido VARCHAR(45) NOT NULL,
#     popularidad INTEGER,
#     estilo VARCHAR(45),
#     PRIMARY KEY(Id_creador)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# (psycopg2.errors.DuplicateTable) la relación «creadores» ya existe
#
# [SQL: CREATE TABLE Creadores( Id_creador INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     apellido VARCHAR(45) NOT NULL,
#     popularidad INTEGER,
#     estilo VARCHAR(45),
#     PRIMARY KEY(Id_creador)
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Tabla "Tipos_NTF"

# %%
# %%sql
#
# CREATE TABLE Tipos_NFT(
#     ID_tipo INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(20) NOT NULL,
#     PRIMARY KEY(ID_tipo)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# (psycopg2.errors.DuplicateTable) la relación «tipos_nft» ya existe
#
# [SQL: CREATE TABLE Tipos_NFT( ID_tipo INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(20) NOT NULL,
#     PRIMARY KEY(ID_tipo)
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Tabla "NFT"

# %%
# %%sql
#
# CREATE TABLE NFT(
#     ID_nft INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     ID_creador INTEGER NOT NULL,
#     FOREIGN KEY (ID_creador) REFERENCES Creadores(ID_creador),
#     id_tipo INTEGER,
#     FOREIGN KEY(ID_tipo) REFERENCES Tipos_NFT(ID_tipo),
#     PRIMARY KEY(ID_nft)
#
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# (psycopg2.errors.DuplicateTable) la relación «nft» ya existe
#
# [SQL: CREATE TABLE NFT( ID_nft INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     ID_creador INTEGER NOT NULL,
#     FOREIGN KEY (ID_creador) REFERENCES Creadores(ID_creador),
#     id_tipo INTEGER,
#     FOREIGN KEY(ID_tipo) REFERENCES Tipos_NFT(ID_tipo),
#     PRIMARY KEY(ID_nft)
#
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Tabla "Precio NFT"

# %%
# %%sql
#
# CREATE TABLE Precio_NFT(
#     ID_nft INTEGER,
#     FOREIGN KEY (ID_nft) REFERENCES NFT(id_nft),
#     fecha TIMESTAMP NOT NULL,
#     precio INTEGER NOT NULL,
#     PRIMARY KEY(id_nft, fecha)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# (psycopg2.errors.DuplicateTable) la relación «precio_nft» ya existe
#
# [SQL: CREATE TABLE Precio_NFT( ID_nft INTEGER,
#     FOREIGN KEY (ID_nft) REFERENCES NFT(id_nft),
#     fecha TIMESTAMP NOT NULL,
#     precio INTEGER NOT NULL,
#     PRIMARY KEY(id_nft, fecha)
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Tabla "Usuario tiene NFT"

# %%
# %%sql
#
# CREATE TABLE Usuario_tiene_NFT(
#     id_usuario INTEGER,
#     id_nft INTEGER,
#
#     FOREIGN KEY (id_usuario) REFERENCES Usuarios(id_usuario),
#     FOREIGN KEY (id_nft) REFERENCES NFT(id_nft),
#
#     PRIMARY KEY (id_usuario, id_nft)
#
#
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# (psycopg2.errors.DuplicateTable) la relación «usuario_tiene_nft» ya existe
#
# [SQL: CREATE TABLE Usuario_tiene_NFT( id_usuario INTEGER,
#     id_nft INTEGER,
#
#     FOREIGN KEY (id_usuario) REFERENCES Usuarios(id_usuario),
#     FOREIGN KEY (id_nft) REFERENCES NFT(id_nft),
#
#     PRIMARY KEY (id_usuario, id_nft)
#
#
# );]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.
#
# PD: Si el codigo tira error por "violar la unicidad de las PK" es por una coincidencia de numeros random, solamente volver a ejecutar el codigo

# %%
#Recuerde haber ejecutado todas las celdas anteriores!

# Generador de timestamp aleatorio.
def generate_timestamp():
    year = r.randint(2015,2022)
    month = r.randint(1,12)
    day = r.randint(1,31)
    
    hour = r.randint(0,23)
    minute = r.randint(0,59)
    second = r.randint(0,59)
    
    if month in [4, 6, 9, 11] and day > 30:
        day = 30
        
    if month == 2 and day > 28:
        day = 28
        
    return datetime(year, month, day, hour, minute, second)

def generate_password():
    return ''.join(r.choice(string.ascii_uppercase + string.digits) for x in range(15))

print("Borrando Datos Antiguos...")

# Limpia la base de datos.
connection.commit() # En caso de algun error
query = "TRUNCATE TABLE usuarios, creadores, tipos_nft, nft, precio_nft, usuario_tiene_nft RESTART IDENTITY"
cursor.execute(query)
connection.commit()


print("Generando Datos...")

nft_names = ['Crypto Raptors', 'The Binary Girl', 'Sphere Art', 'Fight Punks', 'Thunder NFT', 'Artistic Alpha', 'Digital Unicorns', 'Bling Bits', 'Secret Stones', 'Crypto Potato', 'Futuristic Realism', 'Nova Auroras', 'Dreamy Imaginations', 'Reflected Light', 'Spells of Genesis', 'Crypto Felines', 'Dose of Art', 'To The Moon', 'Artful Antlers', 
'Butterfly Dust', 'Depressed Dragons', 'Crypto Diamonds', 'Healthy Hedgehogs', 'Crypto Jackpot', 'Minecraft Sphere', 'Crypto Boom', 'Lucky Lizards', 'Rockin Crypto', 'Crystalline Canyon', 'Koala Kickers', 'Clumsy Crocodiles', 'Mountain of Clouds', 'Blizz Blizzard', 'Cryptokitty Ville', 'Cryptonaut', 'Mike Halloween Yodelers', 'The Teacup Pomeranian', 
'Art Dodger', 'Awesome Concept', 'Aliens Abduction', 'Animated Hard Art', 'Ultimate Iconic Crypto (IUC)', 'Hilarious Horses', '1-Love', '0NOZER0', 'Meteorite NFT', 'Bee Token', 'Elephant Treasure Hunt', 'Crypto Life', '1NiTRO', 'Dust Rift', 'Tokenized Superheroes', 'Techno Abstract Aesthetics', 'Digi Gods', 'Outstanding Octopus', 'Panther NFT', 
'Cypherpunk Samurai', 'Rich Rhinos', 'Crypto Punked', 'Funny Frogs', 'Bit NFT', 'Phonetic Phoenix', 'Flame Stinger', 'Fight For The Title', 'Koalas in Love', 'Touchdown', 'Resilient Rats', 'Bloom of Flowers', 'NFT Lord', 'Fair Coin', 'Art Rumble', 'Light Embrace', 'Crypto Bunny Ranch', 'Crypto Pigeon Race', 'Water Wiggle', 'Wowoo World', 
'Crypto Club', 'Crypto Kitties Of War', 'Visionary Crypto', 'Women Power', 'Rainbows Ends', 'Cards of Polo', 'Crypto Kitties', 'Busy Bats', '0xHile', 'Token Watchdogs', 'Non Fungible Nibbles', 'Pandamonium', '3D Me', 'Midas NFTs', 'Graceful Gorillas', 'United Crypto Token (UCT)', 'Crypto Art Gallery', 'Dark Horse Lady', 'Block View', 'Arty Arts', 
'White Storm', 'Krypto Queen', 'Clever Chimp', 'Qat Tree Unicorn', 'Anna Frozen Entertainers', 'Artificial Rocks', '0NOCH0', 'Flame Blade', 'The Gold Betta', 'Doge Pal', 'Elite Fur Dog Race Club', 'Dust Sifter', 'Moonlit Butterfly', 'Art Lover Box', 'Madame Witch', 'Fantasy Token', 'Bitsy', 'Hive City', 'Couch Potato', 'Burger Bits', 'Crypto Potluck', 
'Cyberboxer', 'Calm Crows', 'Crumbs NFT', 'Mint Chocolates', 'Atollon Coral', 'Dapper Dinos', 'Flame Cats', 'Addictive Animals', 'Alice Wonderland Frozen Carolers', 'Coin Dance', 'Giant Coin', 'Silver Lining Pixy', 'Headed Shark Attack', 'Ultimate League Of Paragon', 'Darker Clouds', 'Blue Mood Chip', 'Brush Point', 'Enthusiastic Elephants', 'Ultra Cool Dogs', 
'Pink Sports Cars']

dominios = ["hola.cl", "google.com","usm.cl","prestigio.usm.cl","crypto.co","basededatos.top"]

tipos_nft = [
    ("Imagen",), ("Musica",),("Juegos",), ("Modelo 3D",), ("Pixel",), ("Membresia",),("Arte",),
]

estilos = [
    ("Anime",),("Manga",),("Arte Retro",),("Arte Moderno",),("Impresionismo",),("Barroco",),("Arte Antiguo",),("Arte 3D",),("Paisaje",)
]

n_usuarios = 200
n_creadores = 20
n_nft = len(nft_names)
n_tipos_nft = len(tipos_nft)
n_usuario_tiene_nft = 80

usuarios = []
for _ in range(1, n_usuarios+1):
    nombre = names.get_first_name()
    apellido = names.get_last_name()
    correo = nombre.lower()+"."+apellido[:4].lower()+"@"+r.choice(dominios)
    usuarios.append((nombre,apellido,correo,generate_password(),generate_timestamp()))

creadores = [(names.get_first_name(), names.get_last_name(), r.randint(0,5), r.choice(estilos)) for _ in range(1,n_creadores+1)]

nft = [(nft_names[n], r.randint(1,n_creadores), r.randint(1,n_tipos_nft)) for n in range(n_nft)]

precio_nft = [(r.randint(1,n_nft), generate_timestamp(), r.randint(500, 100000)) for _ in range(300)]

usuario_tiene_nft = [(r.randint(1,n_usuarios),r.randint(1,n_nft)) for _ in range(81)]


insert = [
    "INSERT INTO usuarios (nombre, apellido, correo, contraseña, fecha_registro) VALUES (%s, %s, %s, %s, %s)",
    "INSERT INTO creadores (nombre, apellido, popularidad, estilo) VALUES (%s, %s, %s, %s)",
    "INSERT INTO tipos_nft (nombre) VALUES (%s)",
    "INSERT INTO nft (nombre, id_creador, id_tipo) VALUES (%s, %s, %s)",
    "INSERT INTO precio_nft (id_nft, fecha, precio) VALUES (%s, %s, %s)",
    "INSERT INTO usuario_tiene_nft (id_usuario, id_nft) VALUES (%s, %s)"
]


for usuario in usuarios:
    cursor.execute(insert[0], usuario)

for creador in creadores:
    cursor.execute(insert[1], creador) 

for tipo in tipos_nft:
    cursor.execute(insert[2], tipo)  

for n in nft:
    cursor.execute(insert[3], n)  
    
for precio in precio_nft:
    cursor.execute(insert[4], precio) 
    
for usr in usuario_tiene_nft:
    cursor.execute(insert[5], usr)
    
connection.commit()

print("Todo Listo!")
# Out:
# Borrando Datos Antiguos...
# Generando Datos...
# Todo Listo!

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **ID y Nombre del creador de un estilo X con mayor popularidad.**
# ###### Si hay más de uno, ponga solamente el primero
#
# Ejemplo:
#
# |Id |  Creador      |
# |---|-----------|
# | 12 |Levi Ackerman |
#
# **Solución:** _Primero renombramos las tablas que utilizaremos, luego en el FROM para utilizar la tabla creadores,_
#  hacemos un WHERE para seleccionar  un estilo de los creadores(este puede ser cambiado) y_
#  finalmente utilizamos el ORDER BY para ordenar la tabla en funcion a la popularidad de los creadores de forma descendiente,
# para extraer el mayor valor de la trabla limitamos a 1._

# %%
# %%sql
#
# SELECT Creadores.ID_creador AS "Id", Creadores.nombre AS "Creador"
# FROM Creadores
# WHERE Creadores.estilo = 'Anime'
# ORDER BY Creadores.popularidad DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 1 rows affected.
# [(19, 'Nathaniel')]

# %% [markdown]
# ### Consulta 2
# **Cantidad de precios que ha tenido históricamente cada NTF.**
#
# Ejemplo:
#
#
# | NFT     | Cantidad de precios |
# |--------------|----------|
# | Minecraft Sphere |    3     |
# | The Binary Girl     |    7     |
# | ...          |   ...    |
#
# **Solución:** _utilizamos un COUNT en el SELECT para que nos retorne el numero de filas de cada ID del NFT asi sabremos cuantos precios tiene un mismo id, luego Unimos las tablas de NFT Y Precio_NFT con un INNER JOIN de acuerdo al ID del nft luego utilizamos el GROUP BY para agrupar las columnas de acuerdo al ID del nft._

# %%
# %%sql
# SELECT NFT.nombre AS "NFT", COUNT(NFT.ID_nft) AS "Cantidad de precios"
# FROM NFT INNER JOIN Precio_NFT
# ON NFT.ID_nft = Precio_NFT.ID_nft
# GROUP BY NFT.ID_nft;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 124 rows affected.
# [('Dust Rift', 1),
#  ('Fair Coin', 2),
#  ('Crypto Diamonds', 2),
#  ('Ultimate Iconic Crypto (IUC)', 2),
#  ('Crumbs NFT', 1),
#  ('Cypherpunk Samurai', 1),
#  ('Artful Antlers', 4),
#  ('Graceful Gorillas', 1),
#  ('Digi Gods', 3),
#  ('Crypto Potato', 3),
#  ('Cryptonaut', 3),
#  ('1NiTRO', 1),
#  ('The Binary Girl', 2),
#  ('Water Wiggle', 2),
#  ('Giant Coin', 2),
#  ('To The Moon', 2),
#  ('Lucky Lizards', 1),
#  ('Rich Rhinos', 1),
#  ('Couch Potato', 2),
#  ('White Storm', 2),
#  ('Dust Sifter', 4),
#  ('Crypto Punked', 4),
#  ('Coin Dance', 5),
#  ('1-Love', 2),
#  ('Block View', 1),
#  ('Koala Kickers', 3),
#  ('Sphere Art', 2),
#  ('Crypto Pigeon Race', 2),
#  ('Cryptokitty Ville', 2),
#  ('Midas NFTs', 1),
#  ('Awesome Concept', 3),
#  ('Cyberboxer', 2),
#  ('Alice Wonderland Frozen Carolers', 3),
#  ('Clever Chimp', 3),
#  ('Nova Auroras', 2),
#  ('Pandamonium', 1),
#  ('Elephant Treasure Hunt', 3),
#  ('Rainbows Ends', 2),
#  ('Thunder NFT', 4),
#  ('Crypto Art Gallery', 1),
#  ('3D Me', 1),
#  ('Clumsy Crocodiles', 1),
#  ('Crypto Kitties Of War', 2),
#  ('Doge Pal', 2),
#  ('Bling Bits', 4),
#  ('Darker Clouds', 5),
#  ('Funny Frogs', 3),
#  ('Koalas in Love', 1),
#  ('Krypto Queen', 2),
#  ('Calm Crows', 6),
#  ('Crypto Boom', 4),
#  ('Light Embrace', 3),
#  ('The Teacup Pomeranian', 3),
#  ('0NOZER0', 1),
#  ('Brush Point', 1),
#  ('Mike Halloween Yodelers', 3),
#  ('Artificial Rocks', 2),
#  ('Dapper Dinos', 1),
#  ('Pink Sports Cars', 2),
#  ('Crypto Jackpot', 2),
#  ('Dark Horse Lady', 4),
#  ('Crypto Life', 1),
#  ('Non Fungible Nibbles', 2),
#  ('Crypto Potluck', 1),
#  ('Aliens Abduction', 3),
#  ('Addictive Animals', 4),
#  ('Hilarious Horses', 1),
#  ('Crystalline Canyon', 1),
#  ('Fight Punks', 1),
#  ('Arty Arts', 1),
#  ('Elite Fur Dog Race Club', 1),
#  ('Token Watchdogs', 1),
#  ('Touchdown', 1),
#  ('Art Dodger', 4),
#  ('Art Lover Box', 1),
#  ('Tokenized Superheroes', 3),
#  ('Anna Frozen Entertainers', 2),
#  ('Futuristic Realism', 1),
#  ('Secret Stones', 1),
#  ('0xHile', 1),
#  ('Depressed Dragons', 1),
#  ('Panther NFT', 9),
#  ('Resilient Rats', 3),
#  ('Animated Hard Art', 2),
#  ('Meteorite NFT', 3),
#  ('Techno Abstract Aesthetics', 2),
#  ('Mountain of Clouds', 3),
#  ('Ultra Cool Dogs', 3),
#  ('Blizz Blizzard', 5),
#  ('Headed Shark Attack', 2),
#  ('Healthy Hedgehogs', 2),
#  ('United Crypto Token (UCT)', 3),
#  ('Enthusiastic Elephants', 3),
#  ('Crypto Bunny Ranch', 1),
#  ('0NOCH0', 3),
#  ('Mint Chocolates', 4),
#  ('Spells of Genesis', 2),
#  ('Bit NFT', 4),
#  ('Flame Blade', 5),
#  ('The Gold Betta', 2),
#  ('Reflected Light', 2),
#  ('Moonlit Butterfly', 4),
#  ('Digital Unicorns', 1),
#  ('Butterfly Dust', 4),
#  ('Crypto Raptors', 6),
#  ('Wowoo World', 3),
#  ('Silver Lining Pixy', 1),
#  ('Art Rumble', 4),
#  ('Bloom of Flowers', 2),
#  ('Fantasy Token', 2),
#  ('Flame Cats', 2),
#  ('Cards of Polo', 1),
#  ('Visionary Crypto', 1),
#  ('Dose of Art', 3),
#  ('Rockin Crypto', 3),
#  ('Crypto Kitties', 4),
#  ('Flame Stinger', 1),
#  ('Madame Witch', 3),
#  ('Crypto Felines', 2),
#  ('Phonetic Phoenix', 3),
#  ('Qat Tree Unicorn', 3),
#  ('Minecraft Sphere', 4),
#  ('Atollon Coral', 2),
#  ('Fight For The Title', 5)]

# %% [markdown]
# ### Consulta 3
# **El nombre y tipo (nombre del tipo) del NFT históricamente más caro.**
# ###### Si hay más de uno, ponga solamente el primero
# Ejemplo:
#
# | NFT    | Tipo |
# |----------------|--------|
# | Minecraft Sphere| Arte 3D |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT NFT.nombre AS "NFT", Tipos_NFT.nombre AS "Tipo"
#
# FROM
#     NFT INNER JOIN Precio_NFT
#     ON NFT.ID_nft = Precio_NFT.ID_nft
#     INNER JOIN Tipos_NFT ON NFT.ID_nft = Tipos_NFT.ID_tipo
#
# ORDER BY Precio_NFT.precio DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 1 rows affected.
# [('Crypto Raptors', 'Imagen')]

# %% [markdown]
# ### Consulta 4
# **Nombre y apellido del usuario con más número de NFTs.**
#
# Ejemplo:
#
# | Nombre     | Apellido |
# |----------------|--------|
# | Levi | Ackerman |
#
# **Solución:** _ con un INNER JOIN unimos la tabla de Usuarios con Usuario_tiene_NFT de acuerdo a los ID de cada uno de estos, para luego con un GROUP BY agruparlos por nombre y apellido finalmete ordenamos de acuerdo al numero de filas de id_usuario de manera descendente para extraer solo la primera fila._

# %%
# %%sql
#
# SELECT
#     Usuarios.nombre AS "Nombre", Usuarios.apellido AS "Apellido"
#
# FROM
#     Usuarios INNER JOIN Usuario_tiene_NFT
#     ON Usuarios.ID_usuario = Usuario_tiene_NFT.id_usuario
#
# GROUP BY Usuarios.nombre, Usuarios.apellido
# ORDER BY COUNT(Usuarios.id_usuario) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 1 rows affected.
# [('Christopher', 'Fischer')]

# %% [markdown]
# ### Consulta 5
# **El NFT que más veces cambió de precio historicamente.**
#
# Ejemplo:
#
# |  ID  | NFT |
# |--------|-------|
# | 11 |Minecraft Sphere |
#
# **Solución:** Primero hacemos un INNER JOIN entre nft y precio_nft, para obtener todas las variaciones de precio que han tenido los NFT con en todas las fechas registradas. Posterior a esto, hacemos un GROUP BY a través del id y el nombre, para poder contar las veces que estas se repiten. Luego ordenamos en orden descendente (de mayor a menor) usando COUNT (es decir, la cantidad de veces que se cambia el precio). Luego lo limitamos a 1, para obtener el mayor valor de cambios (si existe más de uno, escoge alguno sin criterio).

# %%
# %%sql
#
# SELECT precio_nft.id_nft AS "ID", nft.nombre AS "NFT"
#
# FROM
# 	 nft
# 	INNER JOIN precio_nft ON nft.id_nft=precio_nft.id_nft
#
# GROUP BY  precio_nft.id_nft,nft.nombre
# ORDER BY COUNT(precio_nft.id_nft) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 1 rows affected.
# [(56, 'Panther NFT')]

# %% [markdown]
# ### Consulta 6
# **Usuarios que NO tienen un NFT.**
#
# Ejemplo
#
# |Nombre | Apellido|
# |--------|-------|
# |Guillermo    | Diaz |
# |Markus | Person |
# |Rick   | Astley |
# |... | ...|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT
#     Usuarios.nombre AS "Nombre", Usuarios.apellido AS "Apellido"
# FROM
#     Usuarios FULL OUTER JOIN Usuario_tiene_NFT ON Usuarios.ID_usuario = Usuario_tiene_NFT.id_usuario
# WHERE
#     Usuario_tiene_NFT.id_nft is null;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 135 rows affected.
# [('Julie', 'Swamp'),
#  ('Erica', 'Doyle'),
#  ('Reginald', 'Farmer'),
#  ('Gerard', 'Ray'),
#  ('Louis', 'Hamilton'),
#  ('Rhonda', 'Pellicone'),
#  ('Patricia', 'Walker'),
#  ('Carol', 'Kenney'),
#  ('Stephen', 'Lomack'),
#  ('Amy', 'Potts'),
#  ('Marvin', 'Adams'),
#  ('Michelle', 'Quintanilla'),
#  ('Mackenzie', 'Ward'),
#  ('Kevin', 'Lemaire'),
#  ('Anthony', 'Nickel'),
#  ('Mary', 'Perkins'),
#  ('Lola', 'Gober'),
#  ('Patricia', 'Rosado'),
#  ('Brandy', 'Jenkins'),
#  ('Tom', 'Harper'),
#  ('Kelvin', 'Johnson'),
#  ('Bernice', 'Jaimes'),
#  ('Beatriz', 'Briggs'),
#  ('Victoria', 'Brousseau'),
#  ('Gregory', 'Koetter'),
#  ('Eula', 'Haller'),
#  ('Marvin', 'Davis'),
#  ('Susan', 'Tipton'),
#  ('Brenda', 'White'),
#  ('Brandon', 'Lavadera'),
#  ('James', 'Bailey'),
#  ('Althea', 'Brubaker'),
#  ('Sandra', 'Perez'),
#  ('Carl', 'Macklin'),
#  ('Doris', 'Hamblin'),
#  ('Eric', 'Kloeck'),
#  ('Willie', 'Johnson'),
#  ('Betty', 'Pereyra'),
#  ('Shawn', 'Greigo'),
#  ('Mary', 'Keane'),
#  ('Deborah', 'Shope'),
#  ('John', 'Mackin'),
#  ('Sheila', 'Washington'),
#  ('William', 'Moore'),
#  ('Brian', 'Downes'),
#  ('William', 'Epps'),
#  ('Craig', 'Panetta'),
#  ('Roberta', 'Borelli'),
#  ('Will', 'Jones'),
#  ('Betty', 'Estrada'),
#  ('Elizabeth', 'Williamson'),
#  ('Daisy', 'Perez'),
#  ('Amanda', 'Marcus'),
#  ('William', 'Gutierrez'),
#  ('Raymond', 'Henry'),
#  ('Sara', 'Smith'),
#  ('Russell', 'Strain'),
#  ('Roger', 'Estes'),
#  ('Anthony', 'Steffen'),
#  ('Mabel', 'Lafferty'),
#  ('Micah', 'Moore'),
#  ('Larry', 'Deni'),
#  ('Rita', 'Kamerer'),
#  ('Tanya', 'Deloach'),
#  ('Nelda', 'Casillas'),
#  ('Andrea', 'Harrison'),
#  ('John', 'Romero'),
#  ('Marilyn', 'Dunn'),
#  ('George', 'Still'),
#  ('Linda', 'Dougherty'),
#  ('David', 'Henderson'),
#  ('Royce', 'Corrigan'),
#  ('Larry', 'Ostroski'),
#  ('Lazaro', 'Hargrove'),
#  ('Anita', 'Silverstein'),
#  ('Ina', 'Holmes'),
#  ('Marvin', 'Camacho'),
#  ('Judy', 'Moss'),
#  ('Leisa', 'Townsend'),
#  ('Earl', 'Ceaser'),
#  ('Marian', 'Studer'),
#  ('Martha', 'Perkins'),
#  ('Bruno', 'Mead'),
#  ('Josephine', 'Funk'),
#  ('William', 'Bailie'),
#  ('Roberta', 'Carr'),
#  ('Eryn', 'Wiggins'),
#  ('Judith', 'Jones'),
#  ('Christopher', 'Neely'),
#  ('Victor', 'Peckham'),
#  ('Eileen', 'Mccandless'),
#  ('Delbert', 'Mills'),
#  ('Joseph', 'Rehm'),
#  ('Mary', 'Bowman'),
#  ('Carmen', 'Vath'),
#  ('Viola', 'Phillips'),
#  ('Mark', 'Brown'),
#  ('Jacquelyn', 'Dingess'),
#  ('James', 'Ellison'),
#  ('Linda', 'Sweat'),
#  ('Stephen', 'Vineyard'),
#  ('Rebecca', 'Berry'),
#  ('Harrison', 'Wadding'),
#  ('Paul', 'Scheff'),
#  ('John', 'Fryar'),
#  ('Norah', 'Manfre'),
#  ('James', 'Crockett'),
#  ('Patricia', 'Bishop'),
#  ('Pedro', 'Simmons'),
#  ('Patricia', 'Cohen'),
#  ('Debra', 'Combee'),
#  ('Barbara', 'Stubbs'),
#  ('Nellie', 'Griffin'),
#  ('Miriam', 'Oates'),
#  ('Esther', 'Nesslein'),
#  ('Manuel', 'Studer'),
#  ('Dale', 'Cary'),
#  ('Leroy', 'Terwilliger'),
#  ('Maryann', 'Rudisill'),
#  ('Kathryn', 'Perng'),
#  ('Tony', 'Darnell'),
#  ('Charles', 'Stevens'),
#  ('Aubrey', 'Wendolski'),
#  ('Tony', 'Hibler'),
#  ('Judith', 'Patrick'),
#  ('Kory', 'Lacoste'),
#  ('George', 'Hyatt'),
#  ('Seth', 'Wright'),
#  ('Gladys', 'Binkley'),
#  ('Jeannie', 'Kestle'),
#  ('Wade', 'Blood'),
#  ('Jennifer', 'Perkins'),
#  ('Mildred', 'Johnson'),
#  ('Luciano', 'Kenney'),
#  ('Yvonne', 'Gomez')]

# %% [markdown]
# ### Consulta 7
# **Top 4 NFTs más caros actualmente de un id_tipo X .**
#
# Ejemplo:
#
# |NFT |
# |--------|
# |Minecraft Sphere |
# |The Binary Girl |
# |Koalas in Love |
# |Art Dodger |
#
# **Solución:** Primero anidamos una consulta, donde escogemos los precios actuales de todos los NFT. Esto a través de un GROUP BY, y en el SELECT elegimos con MAX la fecha mas reciente. Luego, hacemos un INNER JOIN con el precio nuevamente (para poder obtener el precio en esa fecha), también un INNER JOIN con nft, para obtener el id_tipo correspondiente al id del nft, y hacemos un ultimo INNER JOIN con tipos_nft para obtener el tipo correspondiente. Finalmente, ponemos una condicion en la cual el nombre del tipo debe ser 'Juegos' (puede ser cambiado, este es el id_tipo X). Finalmente ordenamos por precio y lo limitamos a 4, para obtener los 4 mayores

# %%
# %%sql
#
# SELECT nft.nombre AS "NFT"
# FROM(
# 	SELECT precio_nft.id_nft,  MAX(precio_nft.fecha) AS "ultimafecha"
# 	FROM precio_nft
# 	GROUP BY precio_nft.id_nft) AS lastdate
#
# 	INNER JOIN precio_nft
# 	ON precio_nft.fecha=lastdate.ultimafecha
# 	AND precio_nft.id_nft = lastdate.id_nft
#
# 	INNER JOIN nft
# 	ON precio_nft.id_nft=nft.id_nft
#
# 	INNER JOIN tipos_nft
# 	ON tipos_nft.id_tipo=nft.id_tipo
# WHERE tipos_nft.nombre= 'Juegos'
# ORDER BY precio_nft.precio DESC
# LIMIT 4;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 4 rows affected.
# [('Crypto Art Gallery',),
#  ('Bloom of Flowers',),
#  ('Darker Clouds',),
#  ('Phonetic Phoenix',)]

# %% [markdown]
# ### Consulta 8
# **Los precios de todos los NFTs entre los años 2017 y 2019 inclusive.**
#
# Ejemplo:
#
# |NFT |Precio |
# |----|---|
# |Minecraft Sphere |  4000 |
# |The Binary Girl | 3000|
# | Koalas in Love | 6000 |
# |Minecraft Sphere |  1250 |
# | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT nft.nombre AS "NFT", precio_nft.precio AS "Precio"
# FROM precio_nft
# 	INNER JOIN nft
# 	ON precio_nft.id_nft = nft.id_nft
# WHERE
# 	EXTRACT(YEAR FROM precio_nft.fecha) BETWEEN 2017 AND 2019;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 111 rows affected.
# [('Panther NFT', 75653),
#  ('Qat Tree Unicorn', 54056),
#  ('Addictive Animals', 90623),
#  ('Water Wiggle', 92774),
#  ('Darker Clouds', 86173),
#  ('Crypto Felines', 55391),
#  ('Atollon Coral', 87049),
#  ('Fight For The Title', 65140),
#  ('Krypto Queen', 40555),
#  ('Hilarious Horses', 83351),
#  ('Fantasy Token', 22933),
#  ('Dapper Dinos', 57642),
#  ('Crypto Potato', 66986),
#  ('Artificial Rocks', 6815),
#  ('Light Embrace', 23777),
#  ('Crypto Jackpot', 25271),
#  ('Funny Frogs', 87611),
#  ('Moonlit Butterfly', 33789),
#  ('Moonlit Butterfly', 14704),
#  ('Madame Witch', 74204),
#  ('Mountain of Clouds', 90127),
#  ('Crypto Boom', 5364),
#  ('Fight For The Title', 54231),
#  ('Cards of Polo', 40298),
#  ('Futuristic Realism', 81198),
#  ('Fight For The Title', 13608),
#  ('Moonlit Butterfly', 28366),
#  ('The Teacup Pomeranian', 23473),
#  ('Resilient Rats', 27372),
#  ('Touchdown', 27529),
#  ('Minecraft Sphere', 18596),
#  ('Panther NFT', 20039),
#  ('Aliens Abduction', 63899),
#  ('Cypherpunk Samurai', 57686),
#  ('Headed Shark Attack', 89732),
#  ('Light Embrace', 1348),
#  ('Dust Sifter', 30821),
#  ('The Teacup Pomeranian', 37870),
#  ('Panther NFT', 91809),
#  ('Mike Halloween Yodelers', 9301),
#  ('Token Watchdogs', 19733),
#  ('Healthy Hedgehogs', 73019),
#  ('Rainbows Ends', 57342),
#  ('Awesome Concept', 90048),
#  ('Silver Lining Pixy', 8106),
#  ('Mint Chocolates', 94301),
#  ('Ultimate Iconic Crypto (IUC)', 37255),
#  ('Koalas in Love', 50808),
#  ('Coin Dance', 34131),
#  ('Flame Stinger', 89892),
#  ('0NOCH0', 570),
#  ('0NOCH0', 46344),
#  ('The Teacup Pomeranian', 70451),
#  ('Art Dodger', 46864),
#  ('Crypto Kitties', 30590),
#  ('Crypto Kitties', 87095),
#  ('Cryptonaut', 92962),
#  ('Block View', 66900),
#  ('Doge Pal', 28319),
#  ('Flame Blade', 16161),
#  ('Coin Dance', 64192),
#  ('Crypto Raptors', 39144),
#  ('Dust Sifter', 59654),
#  ('Enthusiastic Elephants', 45802),
#  ('Artful Antlers', 64977),
#  ('Clever Chimp', 65194),
#  ('Funny Frogs', 37881),
#  ('Qat Tree Unicorn', 48099),
#  ('Cryptonaut', 91295),
#  ('Non Fungible Nibbles', 52009),
#  ('Crystalline Canyon', 14292),
#  ('Crypto Punked', 36100),
#  ('Crypto Pigeon Race', 53127),
#  ('1-Love', 16876),
#  ('Darker Clouds', 64943),
#  ('Panther NFT', 96119),
#  ('Panther NFT', 81718),
#  ('1-Love', 23503),
#  ('Crypto Jackpot', 22065),
#  ('Crypto Raptors', 44743),
#  ('Mountain of Clouds', 6494),
#  ('Thunder NFT', 55691),
#  ('Alice Wonderland Frozen Carolers', 67541),
#  ('Flame Blade', 3080),
#  ('Enthusiastic Elephants', 72676),
#  ('Wowoo World', 19679),
#  ('Addictive Animals', 38716),
#  ('Minecraft Sphere', 3168),
#  ('Panther NFT', 47757),
#  ('Light Embrace', 23075),
#  ('Elephant Treasure Hunt', 54362),
#  ('Rockin Crypto', 69978),
#  ('Crypto Kitties', 58384),
#  ('0NOZER0', 66826),
#  ('Bit NFT', 84447),
#  ('Healthy Hedgehogs', 41438),
#  ('Elephant Treasure Hunt', 10636),
#  ('Doge Pal', 9859),
#  ('Minecraft Sphere', 1385),
#  ('Dose of Art', 13029),
#  ('Phonetic Phoenix', 26308),
#  ('White Storm', 5254),
#  ('Bling Bits', 14440),
#  ('Butterfly Dust', 28063),
#  ('Rockin Crypto', 45542),
#  ('Enthusiastic Elephants', 44428),
#  ('Pink Sports Cars', 37972),
#  ('Clever Chimp', 30761),
#  ('Bling Bits', 20711),
#  ('Pandamonium', 80150),
#  ('Artful Antlers', 77674)]

# %% [markdown]
# ### Consulta 9
# **Creador al cual le han comprado más NFTs.**
#
# Ejemplo:
#
# |Nombre |Apellido |Cantidad |
# |-|--|-----|
# | Levi |Ackerman |32|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT Tabla.nombre AS "Nombre", Tabla.apellido AS "Apellido", COUNT(Tabla.nombre) AS "Cantidad"
# FROM (
#     SELECT Creadores.ID_creador, NFT.ID_nft, Creadores.nombre, Creadores.apellido
#     FROM NFT INNER JOIN Creadores ON NFT.ID_creador = Creadores.ID_creador
#     GROUP BY Creadores.ID_creador, NFT.ID_nft
#     ) AS Tabla
#     INNER JOIN Usuario_tiene_NFT ON Tabla.id_nft = Usuario_tiene_NFT.id_nft
# GROUP BY Tabla.nombre, Tabla.apellido
# ORDER BY COUNT(Tabla.nombre) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 1 rows affected.
# [('Joseph', 'Barker', 12)]

# %% [markdown]
# ### Consulta 10
# **El NFT con mayor precio actual, que pertenezca a un creador X.**
#
# Ejemplo:
#
# |NFT |Valor|
# |-|-------|
# |Minecraft Sphere |18000|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT nft.nombre AS "NFT", precio_nft.precio AS "Valor"
#  FROM
# 	(SELECT id_nft, MAX(fecha) AS "ultimafecha"
# 	 FROM precio_nft
# 	 GROUP BY id_nft) AS lastprice
#
# 	INNER JOIN precio_nft
# 	ON lastprice.ultimafecha= precio_nft.fecha
# 	AND lastprice.id_nft = precio_nft.id_nft
#
# 	INNER JOIN nft
# 	ON lastprice.id_nft =nft.id_nft
#
# 	INNER JOIN creadores
# 	ON creadores.id_creador = nft.id_creador
# WHERE creadores.nombre='John'
# ORDER BY precio_nft.precio DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 1 rows affected.
# [('Clumsy Crocodiles', 74171)]

# %% [markdown]
# ### Consulta BONUS
# ###### (Vale por un abrazo psicológico)
#
# **El usuario que posee más dinero en NFTs considerando los precios actuales de estos**
#
# Ejemplo:
#
# |Usuario |Dinero|
# |-|-------|
# |Levi Ackerman |8000001|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';
# Out:
#  * postgresql://postgres:***@localhost:5432/Blockchain
# 0 rows affected.
# []
